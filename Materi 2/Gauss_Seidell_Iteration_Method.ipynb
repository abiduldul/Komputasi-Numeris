# %% [markdown]
# <a href="https://colab.research.google.com/github/abiduldul/Numerical-Method/blob/main/Materi%202/Gauss_Seidell_Iteration_Method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sistem persamaan:\
# x + 8y − 2z = −9\
# −2x + 4y − 9z = −50\
# 10x − 3y + 6z = 24,5\
#
# lessgoo dikerjakan menggunakan iterasi Gauss-Seidel

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from IPython.display import display
import pandas as pd

# Matriks A (setelah reordering → diagonal dominan)
A = np.array([
    [10., -3.,  6.],   # 10x - 3y + 6z = 24.5
    [ 1.,  8., -2.],   #  x  + 8y - 2z = -9
    [-2.,  4., -9.]    # -2x + 4y - 9z = -50
], dtype=float)

b = np.array([24.5, -9.0, -50.0], dtype=float)

print("Matriks A (setelah reordering):")
print(A)
print(f"\nVektor b: {b}")
print("\n" + "="*50)
print("CEK DIAGONAL DOMINAN:")
print("="*50)
for i in range(3):
    diag    = abs(A[i, i])
    offdiag = sum(abs(A[i, j]) for j in range(3) if j != i)
    status  = "✅ DOMINAN" if diag > offdiag else "❌ TIDAK DOMINAN"
    print(f"  Baris {i+1}: |{A[i,i]}| = {diag} > {offdiag} (sum off-diag)  →  {status}")

x_exact = np.linalg.solve(A, b)
print(f"\nSolusi Eksak (numpy.linalg): x={x_exact[0]:.4f}, y={x_exact[1]:.4f}, z={x_exact[2]:.4f}")

def gauss_seidel_method(A, b, tol=1e-6, max_iter=100):
    n = len(b)
    x = np.zeros(n)        # tebakan awal [0, 0, 0]
    history = [x.copy()]
    errors  = []

    print("=" * 72)
    print("  ITERASI GAUSS-SEIDEL  —  Update SEKUENSIAL, langsung pakai nilai baru")
    print("=" * 72)
    print(f"  Tebakan awal : x={x[0]}, y={x[1]}, z={x[2]}")
    print(f"  Toleransi    : {tol}")
    print("-" * 72)
    print(f"  {'Iter':>4}  {'x':>12}  {'y':>12}  {'z':>12}  {'Error max|Δ|':>14}")
    print("-" * 72)
    print(f"  {'0':>4}  {x[0]:>12.6f}  {x[1]:>12.6f}  {x[2]:>12.6f}  {'—':>14}")

    for k in range(1, max_iter + 1):
        x_old = x.copy()
        x_new = x.copy()   # akan diupdate satu per satu

        # ── UPDATE SEKUENSIAL: langsung pakai nilai baru ──
        for i in range(n):
            # j < i → sudah dihitung → pakai x_new (nilai baru)
            # j > i → belum dihitung → pakai x (nilai lama = x_new saat ini masih lama)
            sigma    = sum(A[i][j] * x_new[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - sigma) / A[i][i]

        error = np.max(np.abs(x_new - x_old))
        errors.append(error)
        history.append(x_new.copy())

        print(f"  {k:>4}  {x_new[0]:>12.6f}  {x_new[1]:>12.6f}  {x_new[2]:>12.6f}  {error:>14.6e}")

        x = x_new.copy()
        if error < tol:
            break

    print("-" * 72)
    return x, history, errors, k

# Jalankan Gauss-Seidel
tol = 1e-6
x_sol, history, errors, n_iter = gauss_seidel_method(A, b, tol=tol)

print("\n" + "="*55)
print("  HASIL METODE GAUSS-SEIDEL")
print("="*55)
print(f"  Jumlah iterasi : {n_iter}")
print(f"  x              = {x_sol[0]:.8f}")
print(f"  y              = {x_sol[1]:.8f}")
print(f"  z              = {x_sol[2]:.8f}")

print("\n" + "="*55)
print("  VERIFIKASI SUBSTITUSI BALIK")
print("="*55)
xv, yv, zv = x_sol
hasil = [
    ("x + 8y - 2z",    xv + 8*yv - 2*zv,    -9.0),
    ("-2x + 4y - 9z",  -2*xv + 4*yv - 9*zv,  -50.0),
    ("10x - 3y + 6z",  10*xv - 3*yv + 6*zv,   24.5),
]
for expr, val, target in hasil:
    status = "✅" if abs(val - target) < 1e-4 else "❌"
    print(f"  {expr:>15} = {val:>10.4f}  (target: {target:>6})  {status}")

print("\n  Residual ||Ax - b|| =", np.linalg.norm(np.dot(A, x_sol) - b))
print(f"\n  Error vs solusi eksak:")
print(f"    |x - x_exact| = {abs(x_sol[0] - x_exact[0]):.2e}")
print(f"    |y - y_exact| = {abs(x_sol[1] - x_exact[1]):.2e}")
print(f"    |z - z_exact| = {abs(x_sol[2] - x_exact[2]):.2e}")

hist_arr = np.array(history)
df = pd.DataFrame({
    'Iterasi' : range(len(hist_arr)),
    'x'       : hist_arr[:, 0],
    'y'       : hist_arr[:, 1],
    'z'       : hist_arr[:, 2],
    'Error'   : [float('nan')] + errors
})
df_styled = df.style.format({
    'x': '{:.6f}', 'y': '{:.6f}', 'z': '{:.6f}',
    'Error': lambda v: '—' if pd.isna(v) else f'{v:.4e}'
}).set_caption("Riwayat Iterasi Gauss-Seidel")

display(df_styled)

hist_arr = np.array(history)
fig = plt.figure(figsize=(16, 10))
fig.patch.set_facecolor('#f8f9fa')
gs_plot = gridspec.GridSpec(2, 3, figure=fig, hspace=0.45, wspace=0.35)

colors = ['#e74c3c', '#3498db', '#2ecc71']
labels = ['x', 'y', 'z']
exact  = x_exact
# --- Plot : Semua variabel vs iterasi ---
ax1 = fig.add_subplot(gs_plot[0, :3])
for i, (lbl, col) in enumerate(zip(labels, colors)):
    ax1.plot(range(len(hist_arr)), hist_arr[:, i],
             's-', color=col, label=f'Variabel {lbl}',
             linewidth=2, markersize=5)
    ax1.axhline(y=exact[i], color=col, linestyle='--',
                alpha=0.5, linewidth=1.2,
                label=f'{lbl}* = {exact[i]:.2f}')
ax1.set_xlabel('Iterasi', fontsize=11)
ax1.set_ylabel('Nilai Variabel', fontsize=11)
ax1.set_title('Konvergensi Nilai x, y, z — Metode Gauss-Seidel',
              fontsize=13, fontweight='bold')
ax1.legend(fontsize=9, ncol=2, loc='center right')
ax1.grid(True, alpha=0.3)
ax1.set_facecolor('white')

fig.suptitle(
    f'Metode Iterasi Gauss-Seidel  —  Konvergen dalam {n_iter} iterasi\n'
    r'$x + 8y - 2z = -9$  |  $-2x + 4y - 9z = -50$  |  $10x - 3y + 6z = 24.5$',
    fontsize=13, fontweight='bold', y=0.99
)

plt.show()
# Out:
# Matriks A (setelah reordering):
# [[10. -3.  6.]
#  [ 1.  8. -2.]
#  [-2.  4. -9.]]
#
# Vektor b: [ 24.5  -9.  -50. ]
#
# ==================================================
# CEK DIAGONAL DOMINAN:
# ==================================================
#   Baris 1: |10.0| = 10.0 > 9.0 (sum off-diag)  →  ✅ DOMINAN
#   Baris 2: |8.0| = 8.0 > 3.0 (sum off-diag)  →  ✅ DOMINAN
#   Baris 3: |-9.0| = 9.0 > 6.0 (sum off-diag)  →  ✅ DOMINAN
#
# Solusi Eksak (numpy.linalg): x=-1.0000, y=0.5000, z=6.0000
# ========================================================================
#   ITERASI GAUSS-SEIDEL  —  Update SEKUENSIAL, langsung pakai nilai baru
# ========================================================================
#   Tebakan awal : x=0.0, y=0.0, z=0.0
#   Toleransi    : 1e-06
# ------------------------------------------------------------------------
#   Iter             x             y             z    Error max|Δ|
# ------------------------------------------------------------------------
#      0      0.000000      0.000000      0.000000               —
#      1      2.450000     -1.431250      4.375000    4.375000e+00
#      2     -0.604375      0.044297      5.709549    3.054375e+00
#      3     -0.962440      0.422692      5.957294    3.783953e-01
#      4     -0.997569      0.489020      5.994580    6.632753e-02
#      5     -1.000042      0.498650      5.999409    9.630444e-03
#      6     -1.000051      0.499859      5.999948    1.208523e-03
#      7     -1.000011      0.499989      5.999997    1.298738e-04
#      8     -1.000002      0.500000      6.000000    1.106373e-05
#      9     -1.000000      0.500000      6.000000    1.641526e-06
#     10     -1.000000      0.500000      6.000000    2.353304e-07
# ------------------------------------------------------------------------
#
# =======================================================
#   HASIL METODE GAUSS-SEIDEL
# =======================================================
#   Jumlah iterasi : 10
#   x              = -1.00000003
#   y              = 0.50000003
#   z              = 6.00000002
#
# =======================================================
#   VERIFIKASI SUBSTITUSI BALIK
# =======================================================
#       x + 8y - 2z =    -9.0000  (target:   -9.0)  ✅
#     -2x + 4y - 9z =   -50.0000  (target:  -50.0)  ✅
#     10x - 3y + 6z =    24.5000  (target:   24.5)  ✅
#
#   Residual ||Ax - b|| = 3.3430642098101097e-07
#
#   Error vs solusi eksak:
#     |x - x_exact| = 3.25e-08
#     |y - y_exact| = 2.95e-08
#     |z - z_exact| = 2.04e-08
# <style type="text/css">
# </style>
# <table id="T_2465d" class="dataframe">
#   <caption>Riwayat Iterasi Gauss-Seidel</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2465d_level0_col0" class="col_heading level0 col0" >Iterasi</th>
#       <th id="T_2465d_level0_col1" class="col_heading level0 col1" >x</th>
#       <th id="T_2465d_level0_col2" class="col_heading level0 col2" >y</th>
#       <th id="T_2465d_level0_col3" class="col_heading level0 col3" >z</th>
#       <th id="T_2465d_level0_col4" class="col_heading level0 col4" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2465d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2465d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_2465d_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_2465d_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_2465d_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_2465d_row0_col4" class="data row0 col4" >—</td>
#     </tr>
#     <tr>
#       <th id="T_2465d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2465d_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_2465d_row1_col1" class="data row1 col1" >2.450000</td>
#       <td id="T_2465d_row1_col2" class="data row1 col2" >-1.431250</td>
#       <td id="T_2465d_row1_col3" class="data row1 col3" >4.375000</td>
#       <td id="T_2465d_row1_col4" class="data row1 col4" >4.3750e+00</td>
#     </tr>
#     <tr>
#       <th id="T_2465d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2465d_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_2465d_row2_col1" class="data row2 col1" >-0.604375</td>
#       <td id="T_2465d_row2_col2" class="data row2 col2" >0.044297</td>
#       <td id="T_2465d_row2_col3" class="data row2 col3" >5.709549</td>
#       <td id="T_2465d_row2_col4" class="data row2 col4" >3.0544e+00</td>
#     </tr>
#     <tr>
#       <th id="T_2465d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2465d_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_2465d_row3_col1" class="data row3 col1" >-0.962440</td>
#       <td id="T_2465d_row3_col2" class="data row3 col2" >0.422692</td>
#       <td id="T_2465d_row3_col3" class="data row3 col3" >5.957294</td>
#       <td id="T_2465d_row3_col4" class="data row3 col4" >3.7840e-01</td>
#     </tr>
#     <tr>
#       <th id="T_2465d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2465d_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_2465d_row4_col1" class="data row4 col1" >-0.997569</td>
#       <td id="T_2465d_row4_col2" class="data row4 col2" >0.489020</td>
#       <td id="T_2465d_row4_col3" class="data row4 col3" >5.994580</td>
#       <td id="T_2465d_row4_col4" class="data row4 col4" >6.6328e-02</td>
#     </tr>
#     <tr>
#       <th id="T_2465d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2465d_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_2465d_row5_col1" class="data row5 col1" >-1.000042</td>
#       <td id="T_2465d_row5_col2" class="data row5 col2" >0.498650</td>
#       <td id="T_2465d_row5_col3" class="data row5 col3" >5.999409</td>
#       <td id="T_2465d_row5_col4" class="data row5 col4" >9.6304e-03</td>
#     </tr>
#     <tr>
#       <th id="T_2465d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2465d_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_2465d_row6_col1" class="data row6 col1" >-1.000051</td>
#       <td id="T_2465d_row6_col2" class="data row6 col2" >0.499859</td>
#       <td id="T_2465d_row6_col3" class="data row6 col3" >5.999948</td>
#       <td id="T_2465d_row6_col4" class="data row6 col4" >1.2085e-03</td>
#     </tr>
#     <tr>
#       <th id="T_2465d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2465d_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_2465d_row7_col1" class="data row7 col1" >-1.000011</td>
#       <td id="T_2465d_row7_col2" class="data row7 col2" >0.499989</td>
#       <td id="T_2465d_row7_col3" class="data row7 col3" >5.999997</td>
#       <td id="T_2465d_row7_col4" class="data row7 col4" >1.2987e-04</td>
#     </tr>
#     <tr>
#       <th id="T_2465d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2465d_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_2465d_row8_col1" class="data row8 col1" >-1.000002</td>
#       <td id="T_2465d_row8_col2" class="data row8 col2" >0.500000</td>
#       <td id="T_2465d_row8_col3" class="data row8 col3" >6.000000</td>
#       <td id="T_2465d_row8_col4" class="data row8 col4" >1.1064e-05</td>
#     </tr>
#     <tr>
#       <th id="T_2465d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2465d_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_2465d_row9_col1" class="data row9 col1" >-1.000000</td>
#       <td id="T_2465d_row9_col2" class="data row9 col2" >0.500000</td>
#       <td id="T_2465d_row9_col3" class="data row9 col3" >6.000000</td>
#       <td id="T_2465d_row9_col4" class="data row9 col4" >1.6415e-06</td>
#     </tr>
#     <tr>
#       <th id="T_2465d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2465d_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_2465d_row10_col1" class="data row10 col1" >-1.000000</td>
#       <td id="T_2465d_row10_col2" class="data row10 col2" >0.500000</td>
#       <td id="T_2465d_row10_col3" class="data row10 col3" >6.000000</td>
#       <td id="T_2465d_row10_col4" class="data row10 col4" >2.3533e-07</td>
#     </tr>
#   </tbody>
# </table>
