# %% [markdown]
# <a href="https://colab.research.google.com/github/abiduldul/Komputasi-Numeris/blob/main/Materi%201/Secant_Method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Secant Method Code**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define function
def f(x):
    return x**5 + x**3 + 3

# Initial values
x0 = -1.0
x1 = -1.1

tol = 0.001
max_iter = 50

print("Iter |     x_i        |     f(x_i)      |   Error")
print("-"*65)

iterations_x = [x0, x1]

for i in range(1, max_iter+1):

    f_x0 = f(x0)
    f_x1 = f(x1)

    # Secant formula
    x2 = x1 - f_x1 * (x1 - x0) / (f_x1 - f_x0)

    error = abs(x2 - x1)

    print(f"{i:4d} | {x1:12.6f} | {f_x1:14.6f} | {error:10.6f}")

    iterations_x.append(x2)

    if error < tol:
        break

    x0 = x1
    x1 = x2

print("\nConverged Root:")
print(f"x ≈ {x2:.6f}")
print(f"f(x) ≈ {f(x2):.6f}")

# ====== Plot ======
x_vals = np.linspace(-2, 2, 400)
y_vals = f(x_vals)

plt.figure()
plt.plot(x_vals, y_vals)
plt.axhline(0)

# Plot iteration points
for xi in iterations_x:
    plt.scatter(xi, f(xi))

plt.title("Secant Method for f(x) = x^5 + x^3 + 3")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()
# Out:
# Iter |     x_i        |     f(x_i)      |   Error
# -----------------------------------------------------------------
#    1 |    -1.100000 |       0.058490 |   0.006212
#    2 |    -1.106212 |      -0.010183 |   0.000921
#
# Converged Root:
# x ≈ -1.105291
# f(x) ≈ 0.000082
